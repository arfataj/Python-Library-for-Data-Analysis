# %%
import pandas as pd
df = pd.read_csv("sheet2.csv")
df
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 2  01-03-2017         28.0        2.0   Snow         NaN         NaN
# 3  01-04-2017         24.0        7.0   Snow         NaN         NaN
# 4  01-05-2017         32.0        4.0   Rain         NaN         NaN
# 5  01-06-2017         31.0        2.0  Sunny         NaN         NaN
# 6         NaN          NaN        NaN    NaN         NaN         NaN
# 7         NaN          NaN        NaN    NaN         NaN         NaN

# %%
import pandas as pd
weather_data={
    'day':['01-01-2017','01-02-2017','01-03-2017','01-04-2017','01-05-2017','01-06-2017'],
    'temperature':[32,35,28,24,32,31]
}
df=pd.DataFrame(weather_data)
df
# Out:
#           day  temperature
# 0  01-01-2017           32
# 1  01-02-2017           35
# 2  01-03-2017           28
# 3  01-04-2017           24
# 4  01-05-2017           32
# 5  01-06-2017           31

# %%
df
# Out:
#           day  temperature
# 0  01-01-2017           32
# 1  01-02-2017           35
# 2  01-03-2017           28
# 3  01-04-2017           24
# 4  01-05-2017           32
# 5  01-06-2017           31

# %%
import pandas as pd
df = pd.read_csv("sheet2.csv")
df
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 2  01-03-2017         28.0        2.0   Snow         NaN         NaN
# 3  01-04-2017         24.0        7.0   Snow         NaN         NaN
# 4  01-05-2017         32.0        4.0   Rain         NaN         NaN
# 5  01-06-2017         31.0        2.0  Sunny         NaN         NaN
# 6         NaN          NaN        NaN    NaN         NaN         NaN
# 7         NaN          NaN        NaN    NaN         NaN         NaN

# %%
df.shape
# Out:
# (8, 6)

# %%
rows,columns=df.shape

# %%
rows
# Out:
# 8

# %%
columns
# Out:
# 6

# %%
df.head()
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 2  01-03-2017         28.0        2.0   Snow         NaN         NaN
# 3  01-04-2017         24.0        7.0   Snow         NaN         NaN
# 4  01-05-2017         32.0        4.0   Rain         NaN         NaN

# %%
df.head(2)
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN

# %%
df.tail(3)
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 5  01-06-2017         31.0        2.0  Sunny         NaN         NaN
# 6         NaN          NaN        NaN    NaN         NaN         NaN
# 7         NaN          NaN        NaN    NaN         NaN         NaN

# %%
df[2:4]
# Out:
#           day  temperature  windspeed event  Unnamed: 4  Unnamed: 5
# 2  01-03-2017         28.0        2.0  Snow         NaN         NaN
# 3  01-04-2017         24.0        7.0  Snow         NaN         NaN

# %%
df[:]
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 2  01-03-2017         28.0        2.0   Snow         NaN         NaN
# 3  01-04-2017         24.0        7.0   Snow         NaN         NaN
# 4  01-05-2017         32.0        4.0   Rain         NaN         NaN
# 5  01-06-2017         31.0        2.0  Sunny         NaN         NaN
# 6         NaN          NaN        NaN    NaN         NaN         NaN
# 7         NaN          NaN        NaN    NaN         NaN         NaN

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event', 'Unnamed: 4', 'Unnamed: 5'], dtype='object')

# %%
df.day
# Out:
# 0    01-01-2017
# 1    01-02-2017
# 2    01-03-2017
# 3    01-04-2017
# 4    01-05-2017
# 5    01-06-2017
# 6           NaN
# 7           NaN
# Name: day, dtype: object

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# 6      NaN
# 7      NaN
# Name: event, dtype: object

# %%
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# 6      NaN
# 7      NaN
# Name: event, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['temperature','day']]
# Out:
#    temperature         day
# 0         32.0  01-01-2017
# 1         35.0  01-02-2017
# 2         28.0  01-03-2017
# 3         24.0  01-04-2017
# 4         32.0  01-05-2017
# 5         31.0  01-06-2017
# 6          NaN         NaN
# 7          NaN         NaN

# %%
df['temperature'].max()
# Out:
# 35.0

# %%
df['temperature'].min()
# Out:
# 24.0

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed  Unnamed: 4  Unnamed: 5
# count     6.000000   6.000000         0.0         0.0
# mean     30.333333   4.666667         NaN         NaN
# std       3.829708   2.338090         NaN         NaN
# min      24.000000   2.000000         NaN         NaN
# 25%      28.750000   2.500000         NaN         NaN
# 50%      31.500000   5.000000         NaN         NaN
# 75%      32.000000   6.750000         NaN         NaN
# max      35.000000   7.000000         NaN         NaN

# %%
df[df.temperature>=32]
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 4  01-05-2017         32.0        4.0   Rain         NaN         NaN

# %%
df[df.temperature==df.temperature.max()]
# Out:
#           day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 1  01-02-2017         35.0        7.0  Sunny         NaN         NaN

# %%
df[['day','temperature']][df.temperature==df.temperature.max()]
# Out:
#           day  temperature
# 1  01-02-2017         35.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df
# Out:
#             temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# day
# 01-01-2017         32.0        6.0   Rain         NaN         NaN
# 01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 01-03-2017         28.0        2.0   Snow         NaN         NaN
# 01-04-2017         24.0        7.0   Snow         NaN         NaN
# 01-05-2017         32.0        4.0   Rain         NaN         NaN
# 01-06-2017         31.0        2.0  Sunny         NaN         NaN
# NaN                 NaN        NaN    NaN         NaN         NaN
# NaN                 NaN        NaN    NaN         NaN         NaN

# %%
df.index
# Out:
# Index(['01-01-2017', '01-02-2017', '01-03-2017', '01-04-2017', '01-05-2017',
#        '01-06-2017',          nan,          nan],
#       dtype='object', name='day')

# %%
df
# Out:
#             temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# day
# 01-01-2017         32.0        6.0   Rain         NaN         NaN
# 01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 01-03-2017         28.0        2.0   Snow         NaN         NaN
# 01-04-2017         24.0        7.0   Snow         NaN         NaN
# 01-05-2017         32.0        4.0   Rain         NaN         NaN
# 01-06-2017         31.0        2.0  Sunny         NaN         NaN
# NaN                 NaN        NaN    NaN         NaN         NaN
# NaN                 NaN        NaN    NaN         NaN         NaN

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index         day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0      0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1      1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 2      2  01-03-2017         28.0        2.0   Snow         NaN         NaN
# 3      3  01-04-2017         24.0        7.0   Snow         NaN         NaN
# 4      4  01-05-2017         32.0        4.0   Rain         NaN         NaN
# 5      5  01-06-2017         31.0        2.0  Sunny         NaN         NaN
# 6      6         NaN          NaN        NaN    NaN         NaN         NaN
# 7      7         NaN          NaN        NaN    NaN         NaN         NaN

# %%
df.set_index('day')
# Out:
#             index  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# day
# 01-01-2017      0         32.0        6.0   Rain         NaN         NaN
# 01-02-2017      1         35.0        7.0  Sunny         NaN         NaN
# 01-03-2017      2         28.0        2.0   Snow         NaN         NaN
# 01-04-2017      3         24.0        7.0   Snow         NaN         NaN
# 01-05-2017      4         32.0        4.0   Rain         NaN         NaN
# 01-06-2017      5         31.0        2.0  Sunny         NaN         NaN
# NaN             6          NaN        NaN    NaN         NaN         NaN
# NaN             7          NaN        NaN    NaN         NaN         NaN

# %%
df
# Out:
#    index         day  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# 0      0  01-01-2017         32.0        6.0   Rain         NaN         NaN
# 1      1  01-02-2017         35.0        7.0  Sunny         NaN         NaN
# 2      2  01-03-2017         28.0        2.0   Snow         NaN         NaN
# 3      3  01-04-2017         24.0        7.0   Snow         NaN         NaN
# 4      4  01-05-2017         32.0        4.0   Rain         NaN         NaN
# 5      5  01-06-2017         31.0        2.0  Sunny         NaN         NaN
# 6      6         NaN          NaN        NaN    NaN         NaN         NaN
# 7      7         NaN          NaN        NaN    NaN         NaN         NaN

# %%
df.loc['01-03-2017']
# Out:
# index             2
# temperature    28.0
# windspeed       2.0
# event          Snow
# Unnamed: 4      NaN
# Unnamed: 5      NaN
# Name: 01-03-2017, dtype: object

# %%
df
# Out:
#             index  temperature  windspeed  event  Unnamed: 4  Unnamed: 5
# day
# 01-01-2017      0         32.0        6.0   Rain         NaN         NaN
# 01-02-2017      1         35.0        7.0  Sunny         NaN         NaN
# 01-03-2017      2         28.0        2.0   Snow         NaN         NaN
# 01-04-2017      3         24.0        7.0   Snow         NaN         NaN
# 01-05-2017      4         32.0        4.0   Rain         NaN         NaN
# 01-06-2017      5         31.0        2.0  Sunny         NaN         NaN
# NaN             6          NaN        NaN    NaN         NaN         NaN
# NaN             7          NaN        NaN    NaN         NaN         NaN

# %%
df.reset_index(inplace=True)
df
# Out:
#    level_0         day  index  temperature  windspeed  event  Unnamed: 4  \
# 0        0  01-01-2017      0         32.0        6.0   Rain         NaN
# 1        1  01-02-2017      1         35.0        7.0  Sunny         NaN
# 2        2  01-03-2017      2         28.0        2.0   Snow         NaN
# 3        3  01-04-2017      3         24.0        7.0   Snow         NaN
# 4        4  01-05-2017      4         32.0        4.0   Rain         NaN
# 5        5  01-06-2017      5         31.0        2.0  Sunny         NaN
# 6        6         NaN      6          NaN        NaN    NaN         NaN
# 7        7         NaN      7          NaN        NaN    NaN         NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
